# %%
library(reshape2)
library(ggplot2)

# %% [markdown]
# # APS

# %%
df<-read.csv('E:/netData/complexNetdataset/bubbleMatrixData/APStopp10.csv',header = T,encoding = "UTF-8")

# %%
names(df) <- c("X", 'D', '2stepD', 'CD', 'degree' ,'h' ,'PR')

# %%
# melt the data
df_melt <- melt(df, id.vars = "X", variable.name = "variable", value.name = "value")

# convert to percentage and round to two decimal places
df_melt$value <- round(df_melt$value * 100, 2)

# create the ggplot2 plot with text labels
ggplot(df_melt, aes(x = variable, y = X, size = value, alpha = value)) +
  geom_point(color = "#1B4F72", shape = "diamond") +
  geom_text(aes(label = paste0(value, "%")), size = 4.5) +
  scale_size_continuous(range = c(15, 30)) +
  theme(
    panel.background = element_blank(),
    panel.grid = element_line("gray"),
    panel.border = element_rect(colour = "black", fill = NA),
    axis.text = element_text(color = "black", size = 21),
    legend.position = "none",
    panel.grid.major = element_line(color = "#A9CCE3", linetype = "dashed", size = .5)
  ) +
  labs(x = NULL, y = "") +
  scale_alpha_continuous(range = c(0.4, 1))+
  coord_fixed()

ggsave("F:/A J YANG PAPER/Disruption index/JOI DI in complex networks/fig/fig4/APS10.pdf")
# Out:
# Saving 6.67 x 6.67 in image
# plot without title

# %% [markdown]
# # Blogs

# %%
df<-read.csv('E:/netData/complexNetdataset/bubbleMatrixData/Blogstopp10.csv',header = T,encoding = "UTF-8" )

# %%
names(df) <- c("X", 'D', '2stepD', 'CD', 'degree' ,'h' ,'PR')

# %%
# melt the data
df_melt <- melt(df, id.vars = "X", variable.name = "variable", value.name = "value")

# convert to percentage and round to two decimal places
df_melt$value <- round(df_melt$value * 100, 2)

# create the ggplot2 plot with text labels
ggplot(df_melt, aes(x = variable, y = X, size = value, alpha = value)) +
  geom_point(color = "#1B4F72", shape = "diamond") +
  geom_text(aes(label = paste0(value, "%")), size = 4.5) +
  scale_size_continuous(range = c(15, 30)) +
  theme(
    panel.background = element_blank(),
    panel.grid = element_line("gray"),
    panel.border = element_rect(colour = "black", fill = NA),
    axis.text = element_text(color = "black", size = 21),
    legend.position = "none",
    panel.grid.major = element_line(color = "#A9CCE3", linetype = "dashed", size = .5)
  ) +
  labs(x = NULL, y = "") +
  scale_alpha_continuous(range = c(0.4, 1))+
  coord_fixed()

ggsave("F:/A J YANG PAPER/Disruption index/JOI DI in complex networks/fig/fig4/Blogs10.pdf")
# Out:
# Saving 6.67 x 6.67 in image
# plot without title

# %% [markdown]
# # Email

# %%
df<-read.csv('E:/netData/complexNetdataset/bubbleMatrixData/Emailstopp10.csv',header = T,encoding = "UTF-8" )

# %%
names(df) <- c("X", 'D', '2stepD', 'CD', 'degree' ,'h' ,'PR')

# %%
# melt the data
df_melt <- melt(df, id.vars = "X", variable.name = "variable", value.name = "value")

# convert to percentage and round to two decimal places
df_melt$value <- round(df_melt$value * 100, 2)

# create the ggplot2 plot with text labels
ggplot(df_melt, aes(x = variable, y = X, size = value, alpha = value)) +
  geom_point(color = "#1B4F72", shape = "diamond") +
  geom_text(aes(label = paste0(value, "%")), size = 4.5) +
  scale_size_continuous(range = c(15, 30)) +
  theme(
    panel.background = element_blank(),
    panel.grid = element_line("gray"),
    panel.border = element_rect(colour = "black", fill = NA),
    axis.text = element_text(color = "black", size = 21),
    legend.position = "none",
    panel.grid.major = element_line(color = "#A9CCE3", linetype = "dashed", size = .5)
  ) +
  labs(x = NULL, y = "") +
  scale_alpha_continuous(range = c(0.4, 1))+
  coord_fixed()

ggsave("F:/A J YANG PAPER/Disruption index/JOI DI in complex networks/fig/fig4/Emails10.pdf")
# Out:
# Saving 6.67 x 6.67 in image
# plot without title

# %%
df<-read.csv('E:/netData/complexNetdataset/bubbleMatrixData/Wikitopp10.csv',header = T,encoding = "UTF-8" )

# %%
names(df) <- c("X", 'D', '2stepD', 'CD', 'degree' ,'h' ,'PR')

# %%
# melt the data
df_melt <- melt(df, id.vars = "X", variable.name = "variable", value.name = "value")

# convert to percentage and round to two decimal places
df_melt$value <- round(df_melt$value * 100, 2)

# create the ggplot2 plot with text labels
ggplot(df_melt, aes(x = variable, y = X, size = value, alpha = value)) +
  geom_point(color = "#1B4F72", shape = "diamond") +
  geom_text(aes(label = paste0(value, "%")), size = 4.5) +
  scale_size_continuous(range = c(15, 30)) +
  theme(
    panel.background = element_blank(),
    panel.grid = element_line("gray"),
    panel.border = element_rect(colour = "black", fill = NA),
    axis.text = element_text(color = "black", size = 21),
    legend.position = "none",
    panel.grid.major = element_line(color = "#A9CCE3", linetype = "dashed", size = .5)
  ) +
  labs(x = NULL, y = "") +
  scale_alpha_continuous(range = c(0.4, 1))+
  coord_fixed()

ggsave("F:/A J YANG PAPER/Disruption index/JOI DI in complex networks/fig/fig4/Wiki10.pdf")
# Out:
# Saving 6.67 x 6.67 in image
# plot without title
