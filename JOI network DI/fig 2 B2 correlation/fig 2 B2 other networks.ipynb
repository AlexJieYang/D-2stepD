# %%
import pandas as pd
import numpy as np
import random
import seaborn as sns
import matplotlib.pyplot as plt
import scipy
import seaborn

# %% [markdown]
# # WIKI

# %%
df = pd.read_csv(r'E:\netData\complexNetdataset\Wiki-data.csv')

# %%
ff = df[['D', '2stepD','CD','degree','h-index','pagerank']]

# %%
ff = ff.dropna()

# %%
col_name=ff.columns.values
spearman_matrix=scipy.stats.spearmanr(ff).correlation

mask=np.zeros_like(spearman_matrix)
for i in range(1,len(mask)):
    for j in range(0,i):
        mask[j][i]=True
spearman_matrix=pd.DataFrame(spearman_matrix,index=col_name,columns=col_name)#矩阵

# %%
f, ax = plt.subplots(figsize=(10, 7))
sns.set(context='notebook', style='ticks', font_scale=2)
g = seaborn.heatmap(spearman_matrix,annot=True,mask=mask,xticklabels=col_name,yticklabels=col_name, fmt=".2f", linewidth=.5, cmap="crest")#绘制热力图
plt.xticks(size = 25)
plt.yticks(size = 25)
plt.savefig(r"F:\A J YANG PAPER\Disruption index\JOI DI in complex networks\fig\fig2\a1.pdf",bbox_inches = 'tight')

# %%
pd.DataFrame(scipy.stats.spearmanr(ff).pvalue)
# Out:
#               0             1             2             3             4  \
# 0  0.000000e+00  0.000000e+00  0.000000e+00  6.120346e-51  1.868523e-47
# 1  0.000000e+00  0.000000e+00  0.000000e+00  1.087770e-51  3.276596e-48
# 2  0.000000e+00  0.000000e+00  0.000000e+00  1.823534e-50  9.922766e-47
# 3  6.120346e-51  1.087770e-51  1.823534e-50  0.000000e+00  0.000000e+00
# 4  1.868523e-47  3.276596e-48  9.922766e-47  0.000000e+00  0.000000e+00
# 5  9.078549e-10  1.650143e-10  1.874804e-05  0.000000e+00  0.000000e+00
# 6  0.000000e+00  0.000000e+00  0.000000e+00  3.566901e-60  3.692855e-55
#
#               5             6
# 0  9.078549e-10  0.000000e+00
# 1  1.650143e-10  0.000000e+00
# 2  1.874804e-05  0.000000e+00
# 3  0.000000e+00  3.566901e-60
# 4  0.000000e+00  3.692855e-55
# 5  0.000000e+00  2.163983e-09
# 6  2.163983e-09  0.000000e+00

# %% [markdown]
# # Email

# %%
df = pd.read_csv(r'E:\netData\complexNetdataset\email-data.csv')

# %%
ff = df[['D', '2stepD','CD','degree','h-index','pagerank']]

# %%
ff = ff.dropna()

# %%
col_name=ff.columns.values
spearman_matrix=scipy.stats.spearmanr(ff).correlation

mask=np.zeros_like(spearman_matrix)
for i in range(1,len(mask)):
    for j in range(0,i):
        mask[j][i]=True
spearman_matrix=pd.DataFrame(spearman_matrix,index=col_name,columns=col_name)#矩阵

# %%
f, ax = plt.subplots(figsize=(10, 7))
sns.set(context='notebook', style='ticks', font_scale=2)
g = seaborn.heatmap(spearman_matrix,annot=True,mask=mask,xticklabels=col_name,yticklabels=col_name, fmt=".2f", linewidth=.5, cmap="crest")#绘制热力图
plt.xticks(size = 25)
plt.yticks(size = 25)
plt.savefig(r"F:\A J YANG PAPER\Disruption index\JOI DI in complex networks\fig\fig2\a2.pdf",bbox_inches = 'tight')

# %%
pd.DataFrame(scipy.stats.spearmanr(ff).pvalue)
# Out:
#                0              1             2              3              4  \
# 0   0.000000e+00   0.000000e+00  0.000000e+00   2.482908e-02   2.250182e-01
# 1   0.000000e+00   0.000000e+00  0.000000e+00   5.067616e-03   3.940783e-02
# 2   0.000000e+00   0.000000e+00  0.000000e+00   2.240197e-79   8.778174e-73
# 3   2.482908e-02   5.067616e-03  2.240197e-79   0.000000e+00   0.000000e+00
# 4   2.250182e-01   3.940783e-02  8.778174e-73   0.000000e+00   0.000000e+00
# 5  1.306898e-114  2.928975e-106  7.318270e-06  1.596447e-160  7.401004e-131
#
#                5
# 0  1.306898e-114
# 1  2.928975e-106
# 2   7.318270e-06
# 3  1.596447e-160
# 4  7.401004e-131
# 5   0.000000e+00

# %% [markdown]
# # Blogs

# %%
df = pd.read_csv(r'E:\netData\complexNetdataset\blogs-data.csv')

# %%
ff = df[['D', '2stepD','CD','degree','h-index','pagerank']]

# %%
ff = ff.dropna()

# %%
col_name=ff.columns.values
spearman_matrix=scipy.stats.spearmanr(ff).correlation

mask=np.zeros_like(spearman_matrix)
for i in range(1,len(mask)):
    for j in range(0,i):
        mask[j][i]=True
spearman_matrix=pd.DataFrame(spearman_matrix,index=col_name,columns=col_name)#矩阵

# %%
f, ax = plt.subplots(figsize=(10, 7))
sns.set(context='notebook', style='ticks', font_scale=2)
g = seaborn.heatmap(spearman_matrix,annot=True,mask=mask,xticklabels=col_name,yticklabels=col_name, fmt=".2f", linewidth=.5, cmap="crest")#绘制热力图
plt.xticks(size = 25)
plt.yticks(size = 25)
plt.savefig(r"F:\A J YANG PAPER\Disruption index\JOI DI in complex networks\fig\fig2\a3.pdf",bbox_inches = 'tight')

# %%
pd.DataFrame(scipy.stats.spearmanr(ff).pvalue)
# Out:
#               0             1              2              3              4  \
# 0  0.000000e+00  0.000000e+00   4.200997e-84   4.613598e-19   1.915380e-16
# 1  0.000000e+00  0.000000e+00   2.008698e-99   1.918962e-23   1.335857e-22
# 2  4.200997e-84  2.008698e-99   0.000000e+00  2.951260e-185  4.600736e-177
# 3  4.613598e-19  1.918962e-23  2.951260e-185   0.000000e+00   0.000000e+00
# 4  1.915380e-16  1.335857e-22  4.600736e-177   0.000000e+00   0.000000e+00
# 5  3.100723e-06  1.377627e-02  1.015126e-116  2.581887e-182  2.557811e-170
#
#                5
# 0   3.100723e-06
# 1   1.377627e-02
# 2  1.015126e-116
# 3  2.581887e-182
# 4  2.557811e-170
# 5   0.000000e+00
